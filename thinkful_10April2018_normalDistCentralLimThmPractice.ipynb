# %%
#use histrograms and quantile-quantile (QQ) plots to determine if your data is normal

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#making two vars
rand1 = np.random.normal(50, 300, 1000)
rand2 = np.random.poisson(1, 1000)

#sort in ascending order
rand1.sort()
rand2.sort()

#making a std normally dist. var with 100 observations,
# a mean of 0, and stddev of 1 that we will use as out comparison
norm = np.random.normal(0, 1, 1000)

#sorting the values in ascending order
norm.sort()

# %%
#plotting rand1 and rand2 against the norm in qqplots
plt.plot(norm, rand1, "o")
plt.show()

# %%
#plotting rand2 against norm in qqplots
plt.plot(norm, rand2, "o")
plt.show()

# %%
#because out data isn't normal, stddev and mean aren't accurate or informative

# %%
#histogram for rand1
plt.hist(rand1, bins=20, color = 'c')

#add vertical line at mean
plt.axvline(rand1.mean(), color='b', linestyle='solid', linewidth=2)

#add vertical line at one stddev above mean
plt.axvline(rand1.mean()+rand1.std(), color='b', linestyle='dashed', linewidth=2)

#add vertical line at one stddev below mean
plt.axvline(rand1.mean()-rand1.std(), color='b', linestyle='dashed', linewidth=2)

# Print the histogram.
plt.show()

# %%
# Plot the same histogram for rand2.
plt.hist(rand2, bins=20, color = 'c')

# Add a vertical line at the mean.
plt.axvline(rand2.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
plt.axvline(rand2.mean() + rand2.std(), color='b', linestyle='dashed', linewidth=2)

#Add a vertical line at one standard deviation below the mean.
plt.axvline(rand2.mean() - rand2.std(), color='b', linestyle='dashed', linewidth=2)

# Print the histogram.
plt.show()

# %%
#central- limit theorem in action!! whoooh!!
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10, 0.5, 10000)

#make some histograms!
plt.hist(pop1, alpha=0.5, label='Population 1')
plt.hist(pop2, alpha=0.5, label='Population 2')
plt.legend(loc='upper right')
plt.show()

# %%
#these pops aren't normal.
#we're going to take a 100-item sample from each

sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='Sample 1')
plt.hist(sample2, alpha=0.5, label='Sample 2')
plt.legend(loc = 'upper right')

# %%
#means and stddevs
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

diff=sample2.mean()- sample1.mean()
print(diff)
# Out:
# 1.89
# 4.97
# 1.2798046726
# 1.57768818212
# 3.08

# %%
#standard error of the sampling distribution
size = np.array([len(sample1), len(sample2)])
sd = np.array([sample1.std(), sample2.std()])

diff_se = (sum(sd ** 2 / size)) ** 0.5
print(diff/diff_se)
# Out:
# 15.1611966924

# %%
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=15.085200240471774, pvalue=2.5652292333180359e-34)
